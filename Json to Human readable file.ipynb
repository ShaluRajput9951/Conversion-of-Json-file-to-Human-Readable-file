# %%
import json #importing json


f=open('sample.json','r') #opening file as readable type

# %%
data=json.load(f)    #loading json file

# %%
#finding keys of data...
data.keys()  #since file from json is converted into python dictonary
# Out:
# dict_keys(['display_paid', 'paid', 'free', 'display_free'])

# %%
# four keys but two are counting of paid and free....
data["display_paid"]
# Out:
# 1

# %%
data["display_free"]
# Out:
# 1

# %%
data['paid']
# Out:
# [{'emailId': '',
#   'city': 'San Antonio',
#   'twitter_handle': '@shambanit',
#   'keywordSupport': 'HTML,CSS,vanilla Javascript',
#   'country': 'Chile',
#   'imageURL': '"https://storage.googleapis.com/konfhub-bd9c9.appspot.com/48345.jpg?Expires=4718158672&GoogleAccessId=firebase-adminsdk-r3qh4%40konfhub-bd9c9.iam.gserviceaccount.com&Signature=YmTxAU3JAULKdQ%2FhyVszOooug822rJMoKhCs2Bk8%2Bs3mkzgPfUBv%2By8xL1SuCzZST4zliO2PTRIsn1AKs3%2Bft5HpmtViE%2FgIowjPTuyRtREOgebDrs8pBrMO2MfVtpmOZ4tpojSicQmMOKz%2F4K9%2FhoP6%2FHjaBpoqM1VTKzWv059ez5fzaRYKfpAO5%2BOMBs%2B8xlXjeh0mI%2BTjaIsn45BYRr0v9lBN2TBncYaVJTLknOFyTTVQ5QDYLnTj42YyquwUMuen%2FE6ZsURZTOtvh%2BdOJ95rTyBuaXbVfaimr4%2BI4Mp0VQWxMfKGwZjVEXtU%2Bx9WW7NJBkHA2Cr7RmQLnKrxjQ%3D%3D"',
#   'venue': 'Antarctic Peninsula (from San Antonio, Chile)',
#   'searchTerms': ' Antarcticonf, Antarcticonf The Conference At The Edge Of The World, , January, Paid, 1564558672, uruguay ',
#   'confName': 'Antarcticonf The Conference At The Edge Of The World',
# ...

# %%
data['free']
# Out:
# [{'emailId': '',
#   'city': '',
#   'twitter_handle': '',
#   'keywordSupport': ' Artificial Intelligence ,Machine Learning,Cloud',
#   'country': '',
#   'imageURL': 'https://storage.googleapis.com/konfhub-bd9c9.appspot.com/54497.jpg?Expires=4733103270&GoogleAccessId=firebase-adminsdk-r3qh4%40konfhub-bd9c9.iam.gserviceaccount.com&Signature=GSihzq4Vf8koeEGcawKXeQmwT%2FQLZhooWUS%2BqJeNtPXtJqnNfky%2F5RgeOTEWKYCEjqAGFLSEx02cCdZ8CBTO7T2HlMjAZl6yTmDRMTH5mNawUHOrxqjsiNzSwCj4KLqHo8KlEqQrgE%2FTbxmWpT28zKfoOS20C88HrDXFMELmj5aHi4f0V%2BTF30rIlQJkNlFy6fkko2ipkLLxtYOMh0i%2B0tV1vZ0gI21mlpyNzfn6hC%2BGtN1BIz4BciB4IpMkkw7FUydFbXwJOVNm2FJs9AafozJdwdy0gOCtFDrMB2wY8JiPL2oSa%2BkBFlhIgjnIg3LaCPlfj%2Bqn9FTT%2FP5TrOioSg%3D%3D',
#   'venue': 'Online',
#   'searchTerms': ' AWS Innovate Online Conference, Artificial Intelligence ,Machine Learning,Cloud, Online, February, Free, 1579503272, India',
#   'confName': 'AWS Innovate Online Conference',
#   'state': '',
#   'long': '',
# ...

# %%
#actual data lies in 'free; and 'paid' keys
import pandas as pd     #importing pandas to make dataframes...
data_paid=pd.DataFrame(data['paid'])   # storing paid into data_paid


data_paid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   emailId         103 non-null    object
#  1   city            103 non-null    object
#  2   twitter_handle  103 non-null    object
#  3   keywordSupport  103 non-null    object
#  4   country         103 non-null    object
#  5   imageURL        103 non-null    object
#  6   venue           103 non-null    object
#  7   searchTerms     103 non-null    object
#  8   confName        103 non-null    object
#  9   state           103 non-null    object
#  10  long            103 non-null    object
#  11  confEndDate     103 non-null    object
#  12  conference_id   103 non-null    int64
#  13  lat             103 non-null    object
#  14  user_id         103 non-null    object
#  15  confUrl         103 non-null    object
#  16  confStartDate   103 non-null    object
# ...

# %%
data_paid   #printing dataframe...
# Out:
#     emailId           city    twitter_handle  \
# 0              San Antonio        @shambanit
# 1                    Delhi
# 2                  Seattle     @deliveryconf
# 3             Santa Monica       @AppSecCali
# 4                     Oslo  @NDC_Conferences
# ..      ...            ...               ...
# 98                  Lisbon
# 99                 Toronto     @refactorconf
# 100          San Francisco
# 101                 Larvik
# 102              Amsterdam   @CloudNativeFdn
#
#                                    keywordSupport          country  \
# 0                     HTML,CSS,vanilla Javascript            Chile
# 1                                     Cloud, HTML            India
# 2            CICD,  Database,  Serverless,  Azure              USA
# 3     Devops,Building secure API,Web Applications              USA
# 4                   Security, Developer, Software           Norway
# ..                                            ...              ...
# ...

# %%
#storing free into data_free
data_free=pd.DataFrame(data['free'])

# %%
data_free.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   emailId         28 non-null     object
#  1   city            28 non-null     object
#  2   twitter_handle  28 non-null     object
#  3   keywordSupport  28 non-null     object
#  4   country         28 non-null     object
#  5   imageURL        28 non-null     object
#  6   venue           28 non-null     object
#  7   searchTerms     28 non-null     object
#  8   confName        28 non-null     object
#  9   state           28 non-null     object
#  10  long            28 non-null     object
#  11  confEndDate     28 non-null     object
#  12  conference_id   26 non-null     float64
#  13  lat             28 non-null     object
#  14  user_id         28 non-null     object
#  15  confUrl         28 non-null     object
#  16  confStartDate   28 non-null     object
# ...

# %%
data_free
# Out:
#    emailId             city    twitter_handle  \
# 0
# 1                 Bangalore        @redislabs
# 2             San Francisco     @papercall_io
# 3                 Stockholm   @jimmydahlqvist
# 4                   Chennai   @all_conf_alert
# 5                 New Delhi   @all_conf_alert
# 6                   Chicago    @chibrrcon2020
# 7                    Mumbai  @DatacloudGlobal
# 8                      Oslo     @papercall_io
# 9                  Portland  @pycascades-2020
# 10            San Francisco     @papercall_io
# 11                Nashville     @papercall_io
# 12               Huntsville     @papercall_io
# 13                    Omaha  @connectaha-2020
# 14                 Vancover     @papercall_io
# 15                   Mumbai        @Microsoft
# 16                     Kyiv           @fwdays
# 17
# 18                     Kyiv           @fwdays
# 19                                @devops_con
# 20          Washington D.C.    @VoiceSummitAI
# ...

# %%
final_data=pd.concat([data_free,data_paid],ignore_index=True)

# %%
final_data.info()   # total entry ....
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   emailId         131 non-null    object
#  1   city            131 non-null    object
#  2   twitter_handle  131 non-null    object
#  3   keywordSupport  131 non-null    object
#  4   country         131 non-null    object
#  5   imageURL        131 non-null    object
#  6   venue           131 non-null    object
#  7   searchTerms     131 non-null    object
#  8   confName        131 non-null    object
#  9   state           131 non-null    object
#  10  long            131 non-null    object
#  11  confEndDate     131 non-null    object
#  12  conference_id   129 non-null    float64
#  13  lat             131 non-null    object
#  14  user_id         131 non-null    object
#  15  confUrl         131 non-null    object
#  16  confStartDate   131 non-null    object
# ...

# %%
final_data
# Out:
#     emailId           city   twitter_handle  \
# 0
# 1                Bangalore       @redislabs
# 2            San Francisco    @papercall_io
# 3                Stockholm  @jimmydahlqvist
# 4                  Chennai  @all_conf_alert
# ..      ...            ...              ...
# 126                 Lisbon
# 127                Toronto    @refactorconf
# 128          San Francisco
# 129                 Larvik
# 130              Amsterdam  @CloudNativeFdn
#
#                                         keywordSupport          country  \
# 0      Artificial Intelligence ,Machine Learning,Cloud
# 1     Redis, Redis Clustering, Probabilistic Data S...            India
# 2     Threat visibility, Asset inventory, Cloud vs....              USA
# 3                                           AWS, Cloud           Swedan
# 4     Internet of Things, Big Data Analytics, Infor...            India
# ..                                                 ...              ...
# ...
